# %%
import os.path

from collections import Counter
from random import sample

import pandas as pd
import numpy as np

from lda import LDA, datasets as lda_datasets

from newsbreaker.data import load_entries, save_entries

# %%
import os.path
from sklearn.externals import joblib

try:
    topic_model = joblib.load(os.path.join('topic_model', 'topic_model.pkl'))
    
    with open(os.path.join('topic_model', 'vocab.txt')) as f:
        vocab = f.read().split('\n')
except:
    vocab = list(lda_datasets.load_reuters_vocab())
    print('Model not loaded')
# Out:
# Model not loaded

# %%
folder = os.path.join('..', 'data')

# %%
entries = load_entries(folder)

# %%
def build_features(entry):
    doc = entry.doc(False, False, False)

    counter = Counter(
        word.lower_
        for word in doc
    )
    
    return np.array([ counter[word] for word in vocab ])

# %%
X = [
    build_features(entry)
    for entry in entries
]

# %%
# Only use documents that have at least a word in vocab
X = np.array([ row for row in X if row.sum() ])

# %%
# Get indexes of words in vocab that don't show up in any traning document
drop_vocab_indexs = {
    i
    for i, col in enumerate(X.T)
    if not col.sum()
}

# Drop discarded words from vocab
# Now build_features will use only the not discarded
for i in sorted(drop_vocab_indexs, reverse=True):
    vocab.pop(i)

# %%
# Drop any all-zero columns, identified by drop_vocab_indexs
X = np.array([ col for n, col in enumerate(X.T) if n not in drop_vocab_indexs]).T
del drop_vocab_indexs

# %%
# Create and fit model
topic_model = LDA(n_topics=20)
topic_model.fit(X)

# %%
test_entries = sample(entries, 100)
test_vectors = np.array([
    build_features(entry)
    for entry in test_entries
])

# %%
test_Y = topic_model.transform(test_vectors)
# Out:
# WARNING:lda:all zero column in document-term matrix found

# %%
df = pd.DataFrame(
    [
        [res.argmax(), entry.feedname, entry.index, entry.title]
        for entry, res in map(
            lambda pair: (test_entries[pair[0]], pair[1]), 
            enumerate(test_Y)
        )
    ],
    columns=['topic', 'feedname', 'index', 'title']
)

# %%
df.sort_values(by='topic')
# Out:
#     topic           feedname  index  \
# 86      0     ChicagoTribune   2625
# 69      0            NYTimes   1956
# 59      0        StLouisPost  13451
# 27      0  WallStreetJournal    647
# 6       0           USAToday   6968
# 14      1     ChicagoTribune   4496
# 13      1            LATimes  15042
# 32      1        StLouisPost   1053
# 20      1            NYTimes    287
# 53      1          DailyNews   4608
# 36      1            NYTimes     93
# 62      2             NYPost   7474
# 44      2            LATimes   2367
# 1       2            LATimes  12791
# 0       2            LATimes  10449
# 73      3     ChicagoTribune   4399
# 30      3          DailyNews   2807
# 66      3       BostonHerald   2533
# 67      3     ChicagoTribune   2750
# 72      3             NYPost  12391
# 47      3          DailyNews   3203
# 95      3        StLouisPost   6415
# 93      3     WashingtonPost   1669
# 81      3            LATimes  10341
# 7       3             NYPost  13478
# 71      4            LATimes  17532
# 55      4             NYPost  13696
# 68      4            NYTimes   1262
# 38      4            LATimes   9869
# 29      4     ChicagoTribune   2404
# ..    ...                ...    ...
# 2      12            LATimes  15657
# 61     12             NYPost  11698
# 77     12            LATimes  12938
# 39     13          DailyNews   8197
# 85     13             NYPost  11905
# 25     13          DailyNews   5188
# 94     13            NYTimes   4128
# 3      15     ChicagoTribune   3619
# 19     15            LATimes   5303
# 76     15             NYPost   1693
# 23     15       BostonHerald   9695
# 40     15       BostonHerald   4744
# 96     16             NYPost   9961
# 51     16     ChicagoTribune   1356
# 28     16        StLouisPost  14388
# 91     16          DailyNews  12034
# 5      16            LATimes   7598
# 97     17       BostonHerald   7791
# 54     17        StLouisPost  12055
# 49     17        StLouisPost   7455
# 37     17             NYPost  13679
# 10     17            LATimes  14494
# 18     17     WashingtonPost   2618
# 70     18       BostonHerald  12291
# 4      19            LATimes  10810
# 57     19            LATimes   5479
# 26     19             NYPost   4830
# 52     19     WashingtonPost   4788
# 78     19            LATimes   4317
# 89     19       BostonHerald   2662
#
#                                                 title
# 86  Serbia's PM condemns 'brutal treatment' of mig...
# 69             ISIS Damages Temple of Baal in Palmyra
# 59  Obama, Indonesian leader expected to discuss I...
# 27  Stymied at Channel, Migrants With Money Turn t...
# 6   Canadian PM Justin Trudeau says cabinet is hal...
# 14       Walgreens nears deal to buy Rite Aid: report
# 13  Six Flags Entertainment reports attendance jum...
# 32  The rogues gallery of accounting scandals thro...
# 20  Apple Waits as App Developers Study Who’s Buyi...
# 53               Surgeons make the most money: survey
# 36  Amazon Dreams Up a Sale in a Calendar Bursting...
# 62           6 performers who could complete the EGOT
# 44           'Happy Birthday' song could soon be free
# 1   Steven Spielberg's 'Bridge of Spies': Can it c...
# 0   Emmy parties: Oceans of gold — and Amy Schumer...
# 73  Father of Oklahoma parade crash suspect: 'This...
# 30  Youth basketball team attacks homeless with br...
# 66    New Bedford man dead, second man facing charges
# 67  2 shot following dispute in South Side restaurant
# 72  The murder of Officer Randolph Holder was an a...
# 47  Six children, two adults found shot in head at...
# 95  Cousins indicted for shooting up empty histori...
# 93  November trial set for former University of Ci...
# 81  Beverly Hills probes Ferrari race, but Qatari ...
# 7   Guy cited for manspreading on subway was wante...
# 71       USC Now morning report: Trojans get physical
# 55  It might take a few weeks for Carmelo Anthony ...
# 68                    Jets Coach Todd Bowles on Fight
# 38  College football viewer's guide: Game times, c...
# 29  Blackhawks trade Kris Versteeg, Joakim Nordstr...
# ..                                                ...
# 2             Hacienda-style house blends old and new
# 61  Thieves break through walls in ‘Ocean’s 11’-st...
# 77  Under a veil of darkness, Oklahoma removed the...
# 39  Maine mayor wants to list welfare recipients o...
# 85         Ex-journalist repays mag for phony article
# 25  Nestle makes anti-forced labor vow amid allega...
# 94  Amazon Spars With The Times Over Investigative...
# 3   Live blog: Cubs at Pirates and Blackhawks vs. ...
# 19  Dodgers' Kenley Jansen goes from son's birth t...
# 76  AL ‘contenders’ are fakes if they can’t reach ...
# 23  Aces wild: Playoffs open with Astros-Yankees, ...
# 40       Royals&#039; 9th-inning rally buries Red Sox
# 96  Suspect in UVA killing gets 3 life terms for 2...
# 51  Northbrook man pleads guilty in large-scale 's...
# 28  Trial set to start for indicted ex-NY Assembly...
# 91  Sheldon Silver was never offered plea deal: pr...
# 5   L.A.-based trial attorney accused of misapprop...
# 97  Firefighters battle 7-alarm blaze at vacant Ha...
# 54  NOAA: Thanks to El Nino, the US looks pretty w...
# 49  Explosive wildfire threatens California mounta...
# 37  Death toll expected to rise in Romanian nightc...
# 10  L.A. County Sheriff's Department says dogs suf...
# 18  Mexico&#8217;s new plan to protect endangered ...
# 70  Chesney playing Pittsburgh a 2nd time since fa...
# 4   A call for compassion as End of Life Option Ac...
# 57  L.A. leaders' lofty goals are at odds with rea...
# 26  Carl Heastie stands up for common sense on Ind...
# 52  Six amazing science stories that are absolutel...
# 78  'Soft'? 'Hot'? 'Clean'? We help you decode the...
# 89  5 key points from Bobby Jindal&#039;s intervie...
#
# [100 rows x 4 columns]

# %% [markdown]
# # Save model

# %%
joblib.dump(topic_model, os.path.join('topic_model', 'topic_model.pkl'))
# Out:
# ['model_data/topic_model.pkl',
#  'model_data/topic_model.pkl_01.npy',
#  'model_data/topic_model.pkl_02.npy',
#  'model_data/topic_model.pkl_03.npy',
#  'model_data/topic_model.pkl_04.npy',
#  'model_data/topic_model.pkl_05.npy',
#  'model_data/topic_model.pkl_06.npy',
#  'model_data/topic_model.pkl_07.npy']

# %%
with open(os.path.join('topic_model', 'vocab.txt'), 'w') as f:
    f.write('\n'.join(vocab))
